# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

# %%
df = pd.read_csv("./newData.csv",index_col=0)

# %%
df.head()
# Out:
#    Index                                           comments   location  likes
# 0      0               You are truly inspirational to many      mumbai     51
# 1      1    He gives so much hope to us that we can make it  bangalore     51
# 2      2  Congratulations you have been selected among o...    chennai     44
# 3      3                            Most humble footballer     kolkata     33
# 4      4           This is sooo good. Unreal. Love this guy  bangalore     93

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2053 entries, 0 to 2052
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Index     2053 non-null   int64
#  1   comments  2050 non-null   object
#  2   location  2053 non-null   object
#  3   likes     2053 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 80.2+ KB

# %%
counts = df["location"].value_counts()
[print(counts)]
# Out:
# location
# mumbai       429
# delhi        421
# bangalore    415
# chennai      405
# kolkata      383
# Name: count, dtype: int64
# [None]

# %%
plt.scatter(df.location.unique(),counts)

# %%
plt.bar(df.location.unique(),counts)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.pie(counts,labels=df.location.unique(),autopct='% 1.1f %%')
# Out:
# ([<matplotlib.patches.Wedge at 0x11f2c48b0>,
#   <matplotlib.patches.Wedge at 0x11f2c4fd0>,
#   <matplotlib.patches.Wedge at 0x11f2d4790>,
#   <matplotlib.patches.Wedge at 0x11f2d4d00>,
#   <matplotlib.patches.Wedge at 0x11f2e1460>],
#  [Text(0.8713633743992882, 0.6713612066209113, 'mumbai'),
#   Text(-0.414528525673683, 1.0189043632268944, 'bangalore'),
#   Text(-1.0950529930916535, -0.10420624895375212, 'chennai'),
#   Text(-0.24125508919607971, -1.0732175836879452, 'kolkata'),
#   Text(0.9164244974653404, -0.6084128043075676, 'delhi')],
#  [Text(0.4752891133087026, 0.3661970217932243, ' 20.9 %'),
#   Text(-0.22610646854928157, 0.5557660163055786, ' 20.5 %'),
#   Text(-0.5973016325954472, -0.056839772156592056, ' 20.2 %'),
#   Text(-0.13159368501604346, -0.5853914092843336, ' 19.7 %'),
#   Text(0.4998679077083674, -0.3318615296223096, ' 18.7 %')])

# %%
px.scatter(df, 'dislikes' , 'likes','location')
